# %% [markdown]
# # Character-level recurrent sequence-to-sequence model
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2017/09/29<br>
# **Last modified:** 2020/04/26<br>
# **Description:** Character-level recurrent sequence-to-sequence model.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to implement a basic character-level
# recurrent sequence-to-sequence model. We apply it to translating
# short English sentences into short French sentences,
# character-by-character. Note that it is fairly unusual to
# do character-level machine translation, as word-level
# models are more common in this domain.
#
# **Summary of the algorithm**
#
# - We start with input sequences from a domain (e.g. English sentences)
#     and corresponding target sequences from another domain
#     (e.g. French sentences).
# - An encoder LSTM turns input sequences to 2 state vectors
#     (we keep the last LSTM state and discard the outputs).
# - A decoder LSTM is trained to turn the target sequences into
#     the same sequence but offset by one timestep in the future,
#     a training process called "teacher forcing" in this context.
#     It uses as initial state the state vectors from the encoder.
#     Effectively, the decoder learns to generate `targets[t+1...]`
#     given `targets[...t]`, conditioned on the input sequence.
# - In inference mode, when we want to decode unknown input sequences, we:
#     - Encode the input sequence into state vectors
#     - Start with a target sequence of size 1
#         (just the start-of-sequence character)
#     - Feed the state vectors and 1-char target sequence
#         to the decoder to produce predictions for the next character
#     - Sample the next character using these predictions
#         (we simply use argmax).
#     - Append the sampled character to the target sequence
#     - Repeat until we generate the end-of-sequence character or we
#         hit the character limit.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Download the data

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip
# Out:
# ['Archive:  fra-eng.zip',
#  '  inflating: _about.txt              ',
#  '  inflating: fra.txt                 ']

# %% [markdown]
# ## Configuration

# %%
batch_size = 64  # Batch size for training.
epochs = 200  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "fra.txt"

# %% [markdown]
# ## Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/200
# 125/125 [==============================] - 12s 25ms/step - loss: 1.2220 - accuracy: 0.7320 - val_loss: 1.1923 - val_accuracy: 0.7132
# Epoch 2/200
# 125/125 [==============================] - 2s 16ms/step - loss: 0.9423 - accuracy: 0.7480 - val_loss: 0.9661 - val_accuracy: 0.7252
# Epoch 3/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.8429 - accuracy: 0.7660 - val_loss: 0.9106 - val_accuracy: 0.7410
# Epoch 4/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.7525 - accuracy: 0.7909 - val_loss: 0.7894 - val_accuracy: 0.7752
# Epoch 5/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.6718 - accuracy: 0.8073 - val_loss: 0.7349 - val_accuracy: 0.7888
# Epoch 6/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.6300 - accuracy: 0.8170 - val_loss: 0.6869 - val_accuracy: 0.7976
# Epoch 7/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.6013 - accuracy: 0.8241 - val_loss: 0.6637 - val_accuracy: 0.8092
# Epoch 8/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.5792 - accuracy: 0.8294 - val_loss: 0.6408 - val_accuracy: 0.8143
# Epoch 9/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5597 - accuracy: 0.8350 - val_loss: 0.6192 - val_accuracy: 0.8169
# Epoch 10/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.5422 - accuracy: 0.8403 - val_loss: 0.6042 - val_accuracy: 0.8226
# Epoch 11/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.5287 - accuracy: 0.8447 - val_loss: 0.5885 - val_accuracy: 0.8276
# Epoch 12/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.5123 - accuracy: 0.8495 - val_loss: 0.5722 - val_accuracy: 0.8339
# Epoch 13/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4991 - accuracy: 0.8533 - val_loss: 0.5763 - val_accuracy: 0.8317
# Epoch 14/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4864 - accuracy: 0.8567 - val_loss: 0.5523 - val_accuracy: 0.8374
# Epoch 15/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4751 - accuracy: 0.8603 - val_loss: 0.5435 - val_accuracy: 0.8412
# Epoch 16/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4632 - accuracy: 0.8633 - val_loss: 0.5376 - val_accuracy: 0.8424
# Epoch 17/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4526 - accuracy: 0.8665 - val_loss: 0.5221 - val_accuracy: 0.8464
# Epoch 18/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.4436 - accuracy: 0.8691 - val_loss: 0.5139 - val_accuracy: 0.8490
# Epoch 19/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4343 - accuracy: 0.8715 - val_loss: 0.5058 - val_accuracy: 0.8512
# Epoch 20/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4261 - accuracy: 0.8737 - val_loss: 0.5012 - val_accuracy: 0.8522
# Epoch 21/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4190 - accuracy: 0.8759 - val_loss: 0.4948 - val_accuracy: 0.8545
# Epoch 22/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4111 - accuracy: 0.8779 - val_loss: 0.4900 - val_accuracy: 0.8555
# Epoch 23/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4036 - accuracy: 0.8801 - val_loss: 0.4851 - val_accuracy: 0.8571
# Epoch 24/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3970 - accuracy: 0.8823 - val_loss: 0.4830 - val_accuracy: 0.8585
# Epoch 25/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3902 - accuracy: 0.8838 - val_loss: 0.4789 - val_accuracy: 0.8601
# Epoch 26/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3842 - accuracy: 0.8857 - val_loss: 0.4718 - val_accuracy: 0.8609
# Epoch 27/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3782 - accuracy: 0.8875 - val_loss: 0.4721 - val_accuracy: 0.8617
# Epoch 28/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3720 - accuracy: 0.8894 - val_loss: 0.4702 - val_accuracy: 0.8622
# Epoch 29/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3665 - accuracy: 0.8907 - val_loss: 0.4613 - val_accuracy: 0.8639
# Epoch 30/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3609 - accuracy: 0.8924 - val_loss: 0.4648 - val_accuracy: 0.8629
# Epoch 31/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3553 - accuracy: 0.8944 - val_loss: 0.4589 - val_accuracy: 0.8650
# Epoch 32/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3505 - accuracy: 0.8957 - val_loss: 0.4599 - val_accuracy: 0.8647
# Epoch 33/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3452 - accuracy: 0.8972 - val_loss: 0.4586 - val_accuracy: 0.8654
# Epoch 34/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3397 - accuracy: 0.8983 - val_loss: 0.4537 - val_accuracy: 0.8665
# Epoch 35/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3350 - accuracy: 0.8999 - val_loss: 0.4580 - val_accuracy: 0.8651
# Epoch 36/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3302 - accuracy: 0.9012 - val_loss: 0.4483 - val_accuracy: 0.8682
# Epoch 37/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3257 - accuracy: 0.9026 - val_loss: 0.4480 - val_accuracy: 0.8690
# Epoch 38/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3211 - accuracy: 0.9037 - val_loss: 0.4506 - val_accuracy: 0.8684
# Epoch 39/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3165 - accuracy: 0.9055 - val_loss: 0.4472 - val_accuracy: 0.8687
# Epoch 40/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3116 - accuracy: 0.9066 - val_loss: 0.4514 - val_accuracy: 0.8687
# Epoch 41/200
# 125/125 [==============================] - 3s 21ms/step - loss: 0.3076 - accuracy: 0.9078 - val_loss: 0.4443 - val_accuracy: 0.8709
# Epoch 42/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3037 - accuracy: 0.9089 - val_loss: 0.4439 - val_accuracy: 0.8703
# Epoch 43/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2991 - accuracy: 0.9105 - val_loss: 0.4452 - val_accuracy: 0.8713
# Epoch 44/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2946 - accuracy: 0.9118 - val_loss: 0.4438 - val_accuracy: 0.8722
# Epoch 45/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2907 - accuracy: 0.9129 - val_loss: 0.4436 - val_accuracy: 0.8727
# Epoch 46/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2866 - accuracy: 0.9141 - val_loss: 0.4437 - val_accuracy: 0.8727
# Epoch 47/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2826 - accuracy: 0.9151 - val_loss: 0.4415 - val_accuracy: 0.8726
# Epoch 48/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2786 - accuracy: 0.9168 - val_loss: 0.4442 - val_accuracy: 0.8730
# Epoch 49/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2747 - accuracy: 0.9176 - val_loss: 0.4431 - val_accuracy: 0.8731
# Epoch 50/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2710 - accuracy: 0.9189 - val_loss: 0.4443 - val_accuracy: 0.8731
# Epoch 51/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2674 - accuracy: 0.9198 - val_loss: 0.4505 - val_accuracy: 0.8717
# Epoch 52/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2632 - accuracy: 0.9209 - val_loss: 0.4455 - val_accuracy: 0.8741
# Epoch 53/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2595 - accuracy: 0.9221 - val_loss: 0.4451 - val_accuracy: 0.8741
# Epoch 54/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2560 - accuracy: 0.9229 - val_loss: 0.4461 - val_accuracy: 0.8745
# Epoch 55/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2527 - accuracy: 0.9240 - val_loss: 0.4520 - val_accuracy: 0.8729
# Epoch 56/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2490 - accuracy: 0.9254 - val_loss: 0.4462 - val_accuracy: 0.8746
# Epoch 57/200
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2454 - accuracy: 0.9265 - val_loss: 0.4488 - val_accuracy: 0.8749
# Epoch 58/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2418 - accuracy: 0.9275 - val_loss: 0.4490 - val_accuracy: 0.8749
# Epoch 59/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2385 - accuracy: 0.9284 - val_loss: 0.4490 - val_accuracy: 0.8742
# Epoch 60/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2352 - accuracy: 0.9295 - val_loss: 0.4499 - val_accuracy: 0.8763
# Epoch 61/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2322 - accuracy: 0.9301 - val_loss: 0.4551 - val_accuracy: 0.8753
# Epoch 62/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2291 - accuracy: 0.9312 - val_loss: 0.4579 - val_accuracy: 0.8750
# Epoch 63/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2259 - accuracy: 0.9321 - val_loss: 0.4547 - val_accuracy: 0.8752
# Epoch 64/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2224 - accuracy: 0.9333 - val_loss: 0.4574 - val_accuracy: 0.8765
# Epoch 65/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2198 - accuracy: 0.9339 - val_loss: 0.4563 - val_accuracy: 0.8755
# Epoch 66/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2163 - accuracy: 0.9348 - val_loss: 0.4604 - val_accuracy: 0.8761
# Epoch 67/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2133 - accuracy: 0.9358 - val_loss: 0.4587 - val_accuracy: 0.8759
# Epoch 68/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2100 - accuracy: 0.9367 - val_loss: 0.4621 - val_accuracy: 0.8758
# Epoch 69/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2071 - accuracy: 0.9374 - val_loss: 0.4662 - val_accuracy: 0.8753
# Epoch 70/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2043 - accuracy: 0.9383 - val_loss: 0.4686 - val_accuracy: 0.8756
# Epoch 71/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2017 - accuracy: 0.9391 - val_loss: 0.4682 - val_accuracy: 0.8760
# Epoch 72/200
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1984 - accuracy: 0.9402 - val_loss: 0.4707 - val_accuracy: 0.8758
# Epoch 73/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1962 - accuracy: 0.9406 - val_loss: 0.4709 - val_accuracy: 0.8759
# Epoch 74/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1931 - accuracy: 0.9418 - val_loss: 0.4780 - val_accuracy: 0.8757
# Epoch 75/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1905 - accuracy: 0.9423 - val_loss: 0.4790 - val_accuracy: 0.8758
# Epoch 76/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1879 - accuracy: 0.9429 - val_loss: 0.4789 - val_accuracy: 0.8751
# Epoch 77/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1851 - accuracy: 0.9439 - val_loss: 0.4794 - val_accuracy: 0.8760
# Epoch 78/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1825 - accuracy: 0.9448 - val_loss: 0.4777 - val_accuracy: 0.8760
# Epoch 79/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1799 - accuracy: 0.9457 - val_loss: 0.4842 - val_accuracy: 0.8756
# Epoch 80/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1780 - accuracy: 0.9461 - val_loss: 0.4866 - val_accuracy: 0.8756
# Epoch 81/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1754 - accuracy: 0.9468 - val_loss: 0.4906 - val_accuracy: 0.8756
# Epoch 82/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1729 - accuracy: 0.9478 - val_loss: 0.4922 - val_accuracy: 0.8744
# Epoch 83/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1704 - accuracy: 0.9485 - val_loss: 0.4964 - val_accuracy: 0.8755
# Epoch 84/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1678 - accuracy: 0.9490 - val_loss: 0.4935 - val_accuracy: 0.8766
# Epoch 85/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1660 - accuracy: 0.9497 - val_loss: 0.5010 - val_accuracy: 0.8739
# Epoch 86/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1637 - accuracy: 0.9502 - val_loss: 0.4962 - val_accuracy: 0.8763
# Epoch 87/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1618 - accuracy: 0.9509 - val_loss: 0.5005 - val_accuracy: 0.8758
# Epoch 88/200
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1592 - accuracy: 0.9520 - val_loss: 0.5058 - val_accuracy: 0.8753
# Epoch 89/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1570 - accuracy: 0.9525 - val_loss: 0.5045 - val_accuracy: 0.8758
# Epoch 90/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1549 - accuracy: 0.9532 - val_loss: 0.5083 - val_accuracy: 0.8756
# Epoch 91/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1532 - accuracy: 0.9536 - val_loss: 0.5127 - val_accuracy: 0.8756
# Epoch 92/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1506 - accuracy: 0.9543 - val_loss: 0.5135 - val_accuracy: 0.8752
# Epoch 93/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1489 - accuracy: 0.9547 - val_loss: 0.5171 - val_accuracy: 0.8755
# Epoch 94/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1471 - accuracy: 0.9552 - val_loss: 0.5217 - val_accuracy: 0.8747
# Epoch 95/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1448 - accuracy: 0.9557 - val_loss: 0.5210 - val_accuracy: 0.8753
# Epoch 96/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1433 - accuracy: 0.9563 - val_loss: 0.5242 - val_accuracy: 0.8750
# Epoch 97/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1412 - accuracy: 0.9570 - val_loss: 0.5290 - val_accuracy: 0.8757
# Epoch 98/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1395 - accuracy: 0.9575 - val_loss: 0.5314 - val_accuracy: 0.8748
# Epoch 99/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1372 - accuracy: 0.9581 - val_loss: 0.5332 - val_accuracy: 0.8748
# Epoch 100/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1356 - accuracy: 0.9584 - val_loss: 0.5347 - val_accuracy: 0.8751
# Epoch 101/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1335 - accuracy: 0.9591 - val_loss: 0.5366 - val_accuracy: 0.8751
# Epoch 102/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1323 - accuracy: 0.9598 - val_loss: 0.5371 - val_accuracy: 0.8755
# Epoch 103/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1304 - accuracy: 0.9602 - val_loss: 0.5441 - val_accuracy: 0.8750
# Epoch 104/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1292 - accuracy: 0.9604 - val_loss: 0.5471 - val_accuracy: 0.8749
# Epoch 105/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1270 - accuracy: 0.9612 - val_loss: 0.5481 - val_accuracy: 0.8744
# Epoch 106/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1255 - accuracy: 0.9616 - val_loss: 0.5532 - val_accuracy: 0.8734
# Epoch 107/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1237 - accuracy: 0.9620 - val_loss: 0.5534 - val_accuracy: 0.8741
# Epoch 108/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1225 - accuracy: 0.9625 - val_loss: 0.5535 - val_accuracy: 0.8738
# Epoch 109/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1211 - accuracy: 0.9629 - val_loss: 0.5590 - val_accuracy: 0.8743
# Epoch 110/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1196 - accuracy: 0.9633 - val_loss: 0.5625 - val_accuracy: 0.8735
# Epoch 111/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1177 - accuracy: 0.9638 - val_loss: 0.5673 - val_accuracy: 0.8739
# Epoch 112/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1165 - accuracy: 0.9642 - val_loss: 0.5642 - val_accuracy: 0.8747
# Epoch 113/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1151 - accuracy: 0.9646 - val_loss: 0.5763 - val_accuracy: 0.8734
# Epoch 114/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1132 - accuracy: 0.9652 - val_loss: 0.5691 - val_accuracy: 0.8740
# Epoch 115/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1120 - accuracy: 0.9654 - val_loss: 0.5723 - val_accuracy: 0.8738
# Epoch 116/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1104 - accuracy: 0.9659 - val_loss: 0.5791 - val_accuracy: 0.8738
# Epoch 117/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1097 - accuracy: 0.9662 - val_loss: 0.5803 - val_accuracy: 0.8738
# Epoch 118/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1082 - accuracy: 0.9663 - val_loss: 0.5877 - val_accuracy: 0.8738
# Epoch 119/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1070 - accuracy: 0.9669 - val_loss: 0.5889 - val_accuracy: 0.8728
# Epoch 120/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1054 - accuracy: 0.9673 - val_loss: 0.5893 - val_accuracy: 0.8739
# Epoch 121/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1042 - accuracy: 0.9678 - val_loss: 0.5923 - val_accuracy: 0.8731
# Epoch 122/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1036 - accuracy: 0.9678 - val_loss: 0.5916 - val_accuracy: 0.8741
# Epoch 123/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1018 - accuracy: 0.9683 - val_loss: 0.5965 - val_accuracy: 0.8726
# Epoch 124/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1007 - accuracy: 0.9688 - val_loss: 0.6024 - val_accuracy: 0.8731
# Epoch 125/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0994 - accuracy: 0.9691 - val_loss: 0.6040 - val_accuracy: 0.8731
# Epoch 126/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0979 - accuracy: 0.9696 - val_loss: 0.6038 - val_accuracy: 0.8732
# Epoch 127/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0973 - accuracy: 0.9697 - val_loss: 0.6101 - val_accuracy: 0.8736
# Epoch 128/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0957 - accuracy: 0.9704 - val_loss: 0.6141 - val_accuracy: 0.8725
# Epoch 129/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0948 - accuracy: 0.9705 - val_loss: 0.6191 - val_accuracy: 0.8726
# Epoch 130/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0935 - accuracy: 0.9708 - val_loss: 0.6175 - val_accuracy: 0.8728
# Epoch 131/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0929 - accuracy: 0.9707 - val_loss: 0.6168 - val_accuracy: 0.8722
# Epoch 132/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0907 - accuracy: 0.9714 - val_loss: 0.6189 - val_accuracy: 0.8729
# Epoch 133/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0904 - accuracy: 0.9719 - val_loss: 0.6216 - val_accuracy: 0.8724
# Epoch 134/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0894 - accuracy: 0.9719 - val_loss: 0.6298 - val_accuracy: 0.8726
# Epoch 135/200
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0881 - accuracy: 0.9723 - val_loss: 0.6282 - val_accuracy: 0.8728
# Epoch 136/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0871 - accuracy: 0.9729 - val_loss: 0.6415 - val_accuracy: 0.8718
# Epoch 137/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0864 - accuracy: 0.9725 - val_loss: 0.6381 - val_accuracy: 0.8724
# Epoch 138/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0857 - accuracy: 0.9730 - val_loss: 0.6419 - val_accuracy: 0.8724
# Epoch 139/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0844 - accuracy: 0.9733 - val_loss: 0.6430 - val_accuracy: 0.8726
# Epoch 140/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0838 - accuracy: 0.9735 - val_loss: 0.6473 - val_accuracy: 0.8716
# Epoch 141/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0826 - accuracy: 0.9739 - val_loss: 0.6406 - val_accuracy: 0.8727
# Epoch 142/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0817 - accuracy: 0.9738 - val_loss: 0.6536 - val_accuracy: 0.8715
# Epoch 143/200
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0807 - accuracy: 0.9744 - val_loss: 0.6582 - val_accuracy: 0.8713
# Epoch 144/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0800 - accuracy: 0.9745 - val_loss: 0.6553 - val_accuracy: 0.8717
# Epoch 145/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0788 - accuracy: 0.9750 - val_loss: 0.6568 - val_accuracy: 0.8716
# Epoch 146/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0781 - accuracy: 0.9752 - val_loss: 0.6595 - val_accuracy: 0.8724
# Epoch 147/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0775 - accuracy: 0.9752 - val_loss: 0.6566 - val_accuracy: 0.8732
# Epoch 148/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0768 - accuracy: 0.9756 - val_loss: 0.6671 - val_accuracy: 0.8717
# Epoch 149/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0755 - accuracy: 0.9758 - val_loss: 0.6692 - val_accuracy: 0.8720
# Epoch 150/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0754 - accuracy: 0.9760 - val_loss: 0.6728 - val_accuracy: 0.8711
# Epoch 151/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0741 - accuracy: 0.9763 - val_loss: 0.6663 - val_accuracy: 0.8721
# Epoch 152/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0735 - accuracy: 0.9767 - val_loss: 0.6769 - val_accuracy: 0.8708
# Epoch 153/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0728 - accuracy: 0.9769 - val_loss: 0.6812 - val_accuracy: 0.8715
# Epoch 154/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0722 - accuracy: 0.9768 - val_loss: 0.6819 - val_accuracy: 0.8712
# Epoch 155/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0710 - accuracy: 0.9772 - val_loss: 0.6897 - val_accuracy: 0.8718
# Epoch 156/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0706 - accuracy: 0.9770 - val_loss: 0.6863 - val_accuracy: 0.8711
# Epoch 157/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0695 - accuracy: 0.9777 - val_loss: 0.6885 - val_accuracy: 0.8714
# Epoch 158/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0690 - accuracy: 0.9777 - val_loss: 0.6969 - val_accuracy: 0.8705
# Epoch 159/200
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0687 - accuracy: 0.9778 - val_loss: 0.6951 - val_accuracy: 0.8718
# Epoch 160/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0680 - accuracy: 0.9780 - val_loss: 0.6932 - val_accuracy: 0.8709
# Epoch 161/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0669 - accuracy: 0.9785 - val_loss: 0.6978 - val_accuracy: 0.8710
# Epoch 162/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0663 - accuracy: 0.9785 - val_loss: 0.6998 - val_accuracy: 0.8711
# Epoch 163/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0654 - accuracy: 0.9790 - val_loss: 0.7039 - val_accuracy: 0.8709
# Epoch 164/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0647 - accuracy: 0.9790 - val_loss: 0.7089 - val_accuracy: 0.8704
# Epoch 165/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0644 - accuracy: 0.9791 - val_loss: 0.7100 - val_accuracy: 0.8705
# Epoch 166/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0637 - accuracy: 0.9792 - val_loss: 0.7132 - val_accuracy: 0.8704
# Epoch 167/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0631 - accuracy: 0.9794 - val_loss: 0.7103 - val_accuracy: 0.8713
# Epoch 168/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0620 - accuracy: 0.9798 - val_loss: 0.7137 - val_accuracy: 0.8706
# Epoch 169/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0617 - accuracy: 0.9799 - val_loss: 0.7178 - val_accuracy: 0.8712
# Epoch 170/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0612 - accuracy: 0.9800 - val_loss: 0.7200 - val_accuracy: 0.8703
# Epoch 171/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0605 - accuracy: 0.9802 - val_loss: 0.7229 - val_accuracy: 0.8705
# Epoch 172/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0599 - accuracy: 0.9803 - val_loss: 0.7239 - val_accuracy: 0.8705
# Epoch 173/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0597 - accuracy: 0.9803 - val_loss: 0.7242 - val_accuracy: 0.8708
# Epoch 174/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0588 - accuracy: 0.9807 - val_loss: 0.7311 - val_accuracy: 0.8698
# Epoch 175/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0582 - accuracy: 0.9808 - val_loss: 0.7336 - val_accuracy: 0.8702
# Epoch 176/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0576 - accuracy: 0.9812 - val_loss: 0.7330 - val_accuracy: 0.8704
# Epoch 177/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0577 - accuracy: 0.9807 - val_loss: 0.7355 - val_accuracy: 0.8704
# Epoch 178/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0569 - accuracy: 0.9811 - val_loss: 0.7339 - val_accuracy: 0.8701
# Epoch 179/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0561 - accuracy: 0.9815 - val_loss: 0.7359 - val_accuracy: 0.8706
# Epoch 180/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0560 - accuracy: 0.9814 - val_loss: 0.7425 - val_accuracy: 0.8694
# Epoch 181/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0557 - accuracy: 0.9815 - val_loss: 0.7448 - val_accuracy: 0.8708
# Epoch 182/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0545 - accuracy: 0.9820 - val_loss: 0.7478 - val_accuracy: 0.8694
# Epoch 183/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0545 - accuracy: 0.9819 - val_loss: 0.7502 - val_accuracy: 0.8696
# Epoch 184/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0538 - accuracy: 0.9818 - val_loss: 0.7607 - val_accuracy: 0.8691
# Epoch 185/200
# 125/125 [==============================] - 1s 12ms/step - loss: 0.0533 - accuracy: 0.9821 - val_loss: 0.7570 - val_accuracy: 0.8692
# Epoch 186/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0527 - accuracy: 0.9822 - val_loss: 0.7578 - val_accuracy: 0.8696
# Epoch 187/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0523 - accuracy: 0.9823 - val_loss: 0.7629 - val_accuracy: 0.8697
# Epoch 188/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0522 - accuracy: 0.9823 - val_loss: 0.7587 - val_accuracy: 0.8700
# Epoch 189/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0512 - accuracy: 0.9827 - val_loss: 0.7631 - val_accuracy: 0.8688
# Epoch 190/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0511 - accuracy: 0.9826 - val_loss: 0.7629 - val_accuracy: 0.8689
# Epoch 191/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0513 - accuracy: 0.9826 - val_loss: 0.7694 - val_accuracy: 0.8694
# Epoch 192/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0508 - accuracy: 0.9829 - val_loss: 0.7671 - val_accuracy: 0.8693
# Epoch 193/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0502 - accuracy: 0.9829 - val_loss: 0.7754 - val_accuracy: 0.8693
# Epoch 194/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0497 - accuracy: 0.9831 - val_loss: 0.7656 - val_accuracy: 0.8696
# Epoch 195/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0494 - accuracy: 0.9834 - val_loss: 0.7682 - val_accuracy: 0.8694
# Epoch 196/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0487 - accuracy: 0.9834 - val_loss: 0.7736 - val_accuracy: 0.8695
# Epoch 197/200
# 125/125 [==============================] - 2s 14ms/step - loss: 0.0482 - accuracy: 0.9835 - val_loss: 0.7726 - val_accuracy: 0.8684
# Epoch 198/200
# 125/125 [==============================] - 2s 15ms/step - loss: 0.0481 - accuracy: 0.9835 - val_loss: 0.7882 - val_accuracy: 0.8679
# Epoch 199/200
# 125/125 [==============================] - 2s 12ms/step - loss: 0.0479 - accuracy: 0.9835 - val_loss: 0.7787 - val_accuracy: 0.8690
# Epoch 200/200
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0475 - accuracy: 0.9838 - val_loss: 0.7826 - val_accuracy: 0.8699

# %% [markdown]
# ## Run inference (sampling)
#
# 1. encode input and retrieve initial decoder state
# 2. run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token.
# 3. Repeat with the current target token and current states

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %% [markdown]
# You can now generate decoded sentences as such:

# %%
for seq_index in range(0,100,10):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 382ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Go.
# Decoded sentence: En route !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run!
# Decoded sentence: Cours !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# -
# Input sentence: Run.
# Decoded sentence: Cours !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Help!
# Decoded sentence: Soirdez-nous e von !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Wait!
# Decoded sentence: Attends !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Hello!
# Decoded sentence: Salut !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: I won!
# Decoded sentence: J’ai gagné.
#
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Relax.
# Decoded sentence: Détends-toi.
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Attack!
# Decoded sentence: Attaque !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Cheers!
# Decoded sentence: Santé !
