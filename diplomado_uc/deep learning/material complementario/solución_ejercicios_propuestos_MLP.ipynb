# %% [markdown]
# # Parte 1: MLP con imágenes
#
# •Implemente en Keras un MLP con la cantidad de capas y neuronas que prefiera, que permita hacer clasificación de imágenes.
#
# •Entrene la red en CIFAR10 y reporte valores relevantes: velocidad por época, pérdida entrenamiento, pérdida validación, etc.
#
# •Juegue con los hiperparámetros y estructura de la red hasta obtener el rendimiento más alta en el set de validación/test.

# %%
# librerias clasicas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]
plt.rcParams.update({'font.size': 16})

import warnings
warnings.filterwarnings("ignore")

#libreria sklearn
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import datasets, layers, models

# %% [markdown]
# ### Carga del dataset CIFAR-10

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ### Construcción del modelo MLP

# %%
input_shape = (32 ,32, 3) # Imagenes de 32 x 32 con 3 canales

# %%
model = models.Sequential()
model.add(layers.InputLayer(input_shape= input_shape))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_11 (Flatten)        (None, 3072)              0
#
#  dense_51 (Dense)            (None, 256)               786688
#
#  dense_52 (Dense)            (None, 128)               32896
#
#  dense_53 (Dense)            (None, 64)                8256
#
#  dense_54 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 828,490
# Trainable params: 828,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Entrenamiento del Modelo

# %%
train_images.shape
# Out:
# (50000, 32, 32, 3)

# %%
test_images.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# from_logits = TRUE --> Internamente usa softmax

# %%
model.compile(optimizer='adam',
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, batch_size=128, epochs=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 352/352 [==============================] - 5s 12ms/step - loss: 1.9060 - accuracy: 0.3083 - val_loss: 1.7779 - val_accuracy: 0.3646
# Epoch 2/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.7082 - accuracy: 0.3856 - val_loss: 1.7052 - val_accuracy: 0.3916
# Epoch 3/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.6323 - accuracy: 0.4170 - val_loss: 1.6049 - val_accuracy: 0.4362
# Epoch 4/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.5651 - accuracy: 0.4407 - val_loss: 1.5771 - val_accuracy: 0.4462
# Epoch 5/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.5211 - accuracy: 0.4547 - val_loss: 1.5554 - val_accuracy: 0.4488
# Epoch 6/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.4944 - accuracy: 0.4656 - val_loss: 1.5420 - val_accuracy: 0.4536
# Epoch 7/50
# 352/352 [==============================] - 4s 13ms/step - loss: 1.4606 - accuracy: 0.4804 - val_loss: 1.4898 - val_accuracy: 0.4704
# Epoch 8/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.4364 - accuracy: 0.4867 - val_loss: 1.4998 - val_accuracy: 0.4716
# Epoch 9/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.4130 - accuracy: 0.4978 - val_loss: 1.4709 - val_accuracy: 0.4804
# Epoch 10/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.4019 - accuracy: 0.4992 - val_loss: 1.4722 - val_accuracy: 0.4800
# Epoch 11/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.3715 - accuracy: 0.5125 - val_loss: 1.4338 - val_accuracy: 0.4974
# Epoch 12/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.3540 - accuracy: 0.5173 - val_loss: 1.4864 - val_accuracy: 0.4730
# Epoch 13/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.3322 - accuracy: 0.5261 - val_loss: 1.4242 - val_accuracy: 0.4954
# Epoch 14/50
# 352/352 [==============================] - 5s 15ms/step - loss: 1.3190 - accuracy: 0.5299 - val_loss: 1.4418 - val_accuracy: 0.4890
# Epoch 15/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.2987 - accuracy: 0.5343 - val_loss: 1.4118 - val_accuracy: 0.4996
# Epoch 16/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.2820 - accuracy: 0.5426 - val_loss: 1.4187 - val_accuracy: 0.4928
# Epoch 17/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.2647 - accuracy: 0.5476 - val_loss: 1.4118 - val_accuracy: 0.4978
# Epoch 18/50
# 352/352 [==============================] - 5s 13ms/step - loss: 1.2560 - accuracy: 0.5517 - val_loss: 1.4401 - val_accuracy: 0.4930
# Epoch 19/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.2460 - accuracy: 0.5522 - val_loss: 1.4283 - val_accuracy: 0.4972
# Epoch 20/50
# 352/352 [==============================] - 5s 13ms/step - loss: 1.2291 - accuracy: 0.5607 - val_loss: 1.4642 - val_accuracy: 0.5002
# Epoch 21/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.2125 - accuracy: 0.5680 - val_loss: 1.4258 - val_accuracy: 0.5020
# Epoch 22/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.2030 - accuracy: 0.5701 - val_loss: 1.4442 - val_accuracy: 0.4948
# Epoch 23/50
# 352/352 [==============================] - 4s 13ms/step - loss: 1.1867 - accuracy: 0.5766 - val_loss: 1.4231 - val_accuracy: 0.5102
# Epoch 24/50
# 352/352 [==============================] - 4s 13ms/step - loss: 1.1753 - accuracy: 0.5770 - val_loss: 1.4116 - val_accuracy: 0.5102
# Epoch 25/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.1550 - accuracy: 0.5902 - val_loss: 1.4002 - val_accuracy: 0.5106
# Epoch 26/50
# 352/352 [==============================] - 4s 13ms/step - loss: 1.1458 - accuracy: 0.5889 - val_loss: 1.4269 - val_accuracy: 0.5134
# Epoch 27/50
# 352/352 [==============================] - 4s 13ms/step - loss: 1.1384 - accuracy: 0.5939 - val_loss: 1.4235 - val_accuracy: 0.5210
# Epoch 28/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.1235 - accuracy: 0.5974 - val_loss: 1.4404 - val_accuracy: 0.5118
# Epoch 29/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.1173 - accuracy: 0.5989 - val_loss: 1.3752 - val_accuracy: 0.5224
# Epoch 30/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.1033 - accuracy: 0.6070 - val_loss: 1.4752 - val_accuracy: 0.5018
# Epoch 31/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0829 - accuracy: 0.6108 - val_loss: 1.4366 - val_accuracy: 0.5092
# Epoch 32/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0785 - accuracy: 0.6149 - val_loss: 1.4180 - val_accuracy: 0.5184
# Epoch 33/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0691 - accuracy: 0.6167 - val_loss: 1.4175 - val_accuracy: 0.5234
# Epoch 34/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0568 - accuracy: 0.6203 - val_loss: 1.4240 - val_accuracy: 0.5178
# Epoch 35/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0416 - accuracy: 0.6272 - val_loss: 1.4324 - val_accuracy: 0.5136
# Epoch 36/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0398 - accuracy: 0.6244 - val_loss: 1.4237 - val_accuracy: 0.5260
# Epoch 37/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0315 - accuracy: 0.6294 - val_loss: 1.4440 - val_accuracy: 0.5180
# Epoch 38/50
# 352/352 [==============================] - 6s 16ms/step - loss: 1.0202 - accuracy: 0.6348 - val_loss: 1.4869 - val_accuracy: 0.5052
# Epoch 39/50
# 352/352 [==============================] - 5s 13ms/step - loss: 1.0186 - accuracy: 0.6334 - val_loss: 1.4554 - val_accuracy: 0.5132
# Epoch 40/50
# 352/352 [==============================] - 4s 12ms/step - loss: 1.0020 - accuracy: 0.6386 - val_loss: 1.4733 - val_accuracy: 0.5168
# Epoch 41/50
# 352/352 [==============================] - 4s 13ms/step - loss: 0.9952 - accuracy: 0.6422 - val_loss: 1.4810 - val_accuracy: 0.5138
# Epoch 42/50
# 352/352 [==============================] - 4s 12ms/step - loss: 0.9934 - accuracy: 0.6409 - val_loss: 1.4880 - val_accuracy: 0.5122
# Epoch 43/50
# 352/352 [==============================] - 4s 12ms/step - loss: 0.9775 - accuracy: 0.6488 - val_loss: 1.4717 - val_accuracy: 0.5160
# Epoch 44/50
# 352/352 [==============================] - 4s 13ms/step - loss: 0.9663 - accuracy: 0.6519 - val_loss: 1.5009 - val_accuracy: 0.5184
# Epoch 45/50
# 352/352 [==============================] - 4s 12ms/step - loss: 0.9590 - accuracy: 0.6555 - val_loss: 1.5176 - val_accuracy: 0.5070
# Epoch 46/50
# 352/352 [==============================] - 4s 12ms/step - loss: 0.9530 - accuracy: 0.6582 - val_loss: 1.5284 - val_accuracy: 0.5122
# Epoch 47/50
# 352/352 [==============================] - 4s 13ms/step - loss: 0.9444 - accuracy: 0.6600 - val_loss: 1.5547 - val_accuracy: 0.5072
# Epoch 48/50
# 352/352 [==============================] - 5s 13ms/step - loss: 0.9381 - accuracy: 0.6616 - val_loss: 1.5201 - val_accuracy: 0.5140
# Epoch 49/50
# 352/352 [==============================] - 4s 12ms/step - loss: 0.9298 - accuracy: 0.6658 - val_loss: 1.5341 - val_accuracy: 0.5176
# Epoch 50/50
# 352/352 [==============================] - 4s 12ms/step - loss: 0.9283 - accuracy: 0.6654 - val_loss: 1.5959 - val_accuracy: 0.4944

# %% [markdown]
# ### Evaluación

# %%
score = model.evaluate(test_images, test_labels, verbose = 0)
print("Loss en conjunto de test:",round(score[0],3))
print("Accuracy en conjunto de test:", round(score[1],3))
# Out:
# Loss en conjunto de test: 1.59
# Accuracy en conjunto de test: 0.493

# %% [markdown]
# ### Rporte de valores relevantes y gráficos

# %% [markdown]
# **Accuracy**

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %% [markdown]
# **Loss**

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')

# %% [markdown]
# # Parte 2: autoencoder
#
# Un autoencoder es una arquitectura de red neuronal que se utiliza para aprender features generativas, es decir, que permitan generar datos.
# En particular, un autoencoder utiliza un estructura de cuello de botella para generar un output que sea lo más parecido posible al input.
#
# •Utilizando Keras, construya y entrene autoencoders para alguno de los sets de datos disponibles.
#
# •Haga un análisis de sensibilidad para el código (code en la figura), graficando su tamaño vs la pérdida de reconstrucción promedio. Compare estos valores para los sets de entrenamiento y validación/test.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Carga de datos

# %%
(x_train, y_train), (x_test, y_test) = datasets.fashion_mnist.load_data()

# %%
# Normalize pixel values to be between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)

    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ### Construcción del modelo

# %%
def build_autoencoder(input_shape, representation_size):
    encoder = models.Sequential()
    encoder.add(layers.InputLayer(input_shape=input_shape))
    encoder.add(layers.Flatten())
    encoder.add(layers.Dense(256, activation='relu'))
    encoder.add(layers.Dense(128, activation='relu'))
    encoder.add(layers.Dense(representation_size, activation='relu'))

    decoder = models.Sequential()
    decoder.add(layers.Dense(128, activation='sigmoid'))
    decoder.add(layers.Dense(256, activation='sigmoid'))
    decoder.add(layers.Dense(np.prod(input_shape), activation='sigmoid'))
    decoder.add(layers.Reshape(input_shape)) # "Unflatten"

    model = models.Sequential()
    model.add(layers.InputLayer(input_shape=input_shape))
    model.add(encoder)
    model.add(decoder)

    return model, encoder, decoder

# %%
input_shape = x_train.shape[1:]

# %% [markdown]
# ## Representación de tamaño 16

# %%
model16, encoder, decoder = build_autoencoder(input_shape, 16)

# %%
model16.summary(expand_nested=True)
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_18 (Sequential)  (None, 16)                235920
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | flatten_6 (Flatten)       (None, 784)               0         |
# |                                                               |
# | dense_24 (Dense)          (None, 256)               200960    |
# |                                                               |
# | dense_25 (Dense)          (None, 128)               32896     |
# |                                                               |
# | dense_26 (Dense)          (None, 16)                2064      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  sequential_19 (Sequential)  (None, 28, 28)            236688
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | dense_27 (Dense)          (None, 128)               2176      |
# |                                                               |
# | dense_28 (Dense)          (None, 256)               33024     |
# |                                                               |
# | dense_29 (Dense)          (None, 784)               201488    |
# |                                                               |
# | reshape_6 (Reshape)       (None, 28, 28)            0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 472,608
# Trainable params: 472,608
# Non-trainable params: 0
# _________________________________________________________________

# %%
model16.compile(optimizer='adam', loss='binary_crossentropy')

history16 = model16.fit(x_train, x_train, batch_size=128, epochs=50, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.3900 - val_loss: 0.3445
# Epoch 2/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3280 - val_loss: 0.3205
# Epoch 3/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3135 - val_loss: 0.3125
# Epoch 4/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.3074 - val_loss: 0.3071
# Epoch 5/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3028 - val_loss: 0.3033
# Epoch 6/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2993 - val_loss: 0.3002
# Epoch 7/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2965 - val_loss: 0.2977
# Epoch 8/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2941 - val_loss: 0.2955
# Epoch 9/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2923 - val_loss: 0.2939
# Epoch 10/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2906 - val_loss: 0.2925
# Epoch 11/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2892 - val_loss: 0.2909
# Epoch 12/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2879 - val_loss: 0.2903
# Epoch 13/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2867 - val_loss: 0.2891
# Epoch 14/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2858 - val_loss: 0.2880
# Epoch 15/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2850 - val_loss: 0.2873
# Epoch 16/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2843 - val_loss: 0.2868
# Epoch 17/50
# 422/422 [==============================] - 6s 15ms/step - loss: 0.2836 - val_loss: 0.2859
# Epoch 18/50
# 422/422 [==============================] - 9s 22ms/step - loss: 0.2831 - val_loss: 0.2856
# Epoch 19/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2826 - val_loss: 0.2850
# Epoch 20/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2821 - val_loss: 0.2847
# Epoch 21/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2817 - val_loss: 0.2844
# Epoch 22/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2813 - val_loss: 0.2839
# Epoch 23/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2809 - val_loss: 0.2836
# Epoch 24/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2807 - val_loss: 0.2834
# Epoch 25/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2803 - val_loss: 0.2831
# Epoch 26/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2800 - val_loss: 0.2829
# Epoch 27/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2797 - val_loss: 0.2823
# Epoch 28/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2793 - val_loss: 0.2821
# Epoch 29/50
# 422/422 [==============================] - 7s 16ms/step - loss: 0.2791 - val_loss: 0.2818
# Epoch 30/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2788 - val_loss: 0.2816
# Epoch 31/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2786 - val_loss: 0.2815
# Epoch 32/50
# 422/422 [==============================] - 7s 17ms/step - loss: 0.2784 - val_loss: 0.2812
# Epoch 33/50
# 422/422 [==============================] - 8s 19ms/step - loss: 0.2781 - val_loss: 0.2811
# Epoch 34/50
# 422/422 [==============================] - 7s 16ms/step - loss: 0.2780 - val_loss: 0.2809
# Epoch 35/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2778 - val_loss: 0.2808
# Epoch 36/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2776 - val_loss: 0.2805
# Epoch 37/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2774 - val_loss: 0.2803
# Epoch 38/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2773 - val_loss: 0.2805
# Epoch 39/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2771 - val_loss: 0.2801
# Epoch 40/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2770 - val_loss: 0.2800
# Epoch 41/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2768 - val_loss: 0.2800
# Epoch 42/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2767 - val_loss: 0.2798
# Epoch 43/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2766 - val_loss: 0.2799
# Epoch 44/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2765 - val_loss: 0.2796
# Epoch 45/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2764 - val_loss: 0.2795
# Epoch 46/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2763 - val_loss: 0.2793
# Epoch 47/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2762 - val_loss: 0.2795
# Epoch 48/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2761 - val_loss: 0.2792
# Epoch 49/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2760 - val_loss: 0.2792
# Epoch 50/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2759 - val_loss: 0.2791

# %%
plt.plot(history16.history['loss'], label='loss')
plt.plot(history16.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %%
decoded_imgs = model16(x_test[:10])

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    plt.title("Original", fontsize=12)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    plt.title("Reconstructed", fontsize=12)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Representación de tamaño 32

# %%
model32, encoder, decoder = build_autoencoder(input_shape, 32)

# %%
model32.summary(expand_nested=True)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_21 (Sequential)  (None, 32)                237984
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | flatten_7 (Flatten)       (None, 784)               0         |
# |                                                               |
# | dense_30 (Dense)          (None, 256)               200960    |
# |                                                               |
# | dense_31 (Dense)          (None, 128)               32896     |
# |                                                               |
# | dense_32 (Dense)          (None, 32)                4128      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  sequential_22 (Sequential)  (None, 28, 28)            238736
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | dense_33 (Dense)          (None, 128)               4224      |
# |                                                               |
# | dense_34 (Dense)          (None, 256)               33024     |
# |                                                               |
# | dense_35 (Dense)          (None, 784)               201488    |
# |                                                               |
# | reshape_7 (Reshape)       (None, 28, 28)            0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 476,720
# Trainable params: 476,720
# Non-trainable params: 0
# _________________________________________________________________

# %%
model32.compile(optimizer='adam', loss='binary_crossentropy')

history32 = model32.fit(x_train, x_train, batch_size=128, epochs=50, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/50
# 422/422 [==============================] - 6s 12ms/step - loss: 0.3946 - val_loss: 0.3433
# Epoch 2/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3250 - val_loss: 0.3183
# Epoch 3/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.3111 - val_loss: 0.3096
# Epoch 4/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3046 - val_loss: 0.3046
# Epoch 5/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3001 - val_loss: 0.3004
# Epoch 6/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2965 - val_loss: 0.2974
# Epoch 7/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2938 - val_loss: 0.2950
# Epoch 8/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2914 - val_loss: 0.2926
# Epoch 9/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2892 - val_loss: 0.2906
# Epoch 10/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2873 - val_loss: 0.2900
# Epoch 11/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2856 - val_loss: 0.2872
# Epoch 12/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2841 - val_loss: 0.2858
# Epoch 13/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2827 - val_loss: 0.2846
# Epoch 14/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2815 - val_loss: 0.2836
# Epoch 15/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2805 - val_loss: 0.2826
# Epoch 16/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2796 - val_loss: 0.2822
# Epoch 17/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2789 - val_loss: 0.2815
# Epoch 18/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2781 - val_loss: 0.2804
# Epoch 19/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2775 - val_loss: 0.2799
# Epoch 20/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2769 - val_loss: 0.2793
# Epoch 21/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2763 - val_loss: 0.2787
# Epoch 22/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2758 - val_loss: 0.2782
# Epoch 23/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2754 - val_loss: 0.2777
# Epoch 24/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2748 - val_loss: 0.2772
# Epoch 25/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2745 - val_loss: 0.2769
# Epoch 26/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2741 - val_loss: 0.2766
# Epoch 27/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2736 - val_loss: 0.2762
# Epoch 28/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2733 - val_loss: 0.2759
# Epoch 29/50
# 422/422 [==============================] - 7s 15ms/step - loss: 0.2730 - val_loss: 0.2759
# Epoch 30/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2727 - val_loss: 0.2754
# Epoch 31/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2724 - val_loss: 0.2751
# Epoch 32/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2721 - val_loss: 0.2747
# Epoch 33/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2718 - val_loss: 0.2745
# Epoch 34/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2716 - val_loss: 0.2742
# Epoch 35/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2714 - val_loss: 0.2740
# Epoch 36/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2711 - val_loss: 0.2738
# Epoch 37/50
# 422/422 [==============================] - 6s 15ms/step - loss: 0.2709 - val_loss: 0.2736
# Epoch 38/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2708 - val_loss: 0.2734
# Epoch 39/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2706 - val_loss: 0.2734
# Epoch 40/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2704 - val_loss: 0.2737
# Epoch 41/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2702 - val_loss: 0.2731
# Epoch 42/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2700 - val_loss: 0.2727
# Epoch 43/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2699 - val_loss: 0.2726
# Epoch 44/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2697 - val_loss: 0.2725
# Epoch 45/50
# 422/422 [==============================] - 6s 15ms/step - loss: 0.2696 - val_loss: 0.2726
# Epoch 46/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2695 - val_loss: 0.2723
# Epoch 47/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2694 - val_loss: 0.2723
# Epoch 48/50
# 422/422 [==============================] - 6s 14ms/step - loss: 0.2692 - val_loss: 0.2720
# Epoch 49/50
# 422/422 [==============================] - 6s 13ms/step - loss: 0.2691 - val_loss: 0.2723
# Epoch 50/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2690 - val_loss: 0.2719

# %%
plt.plot(history32.history['loss'], label='loss')
plt.plot(history32.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %%
decoded_imgs = model32(x_test[:10])

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    plt.title("Original", fontsize=12)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    plt.title("Reconstructed", fontsize=12)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Representación de tamaño 64

# %%
model64, encoder, decoder = build_autoencoder(input_shape, 64)

# %%
model64.summary(expand_nested=True)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_24 (Sequential)  (None, 64)                242112
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | flatten_8 (Flatten)       (None, 784)               0         |
# |                                                               |
# | dense_36 (Dense)          (None, 256)               200960    |
# |                                                               |
# | dense_37 (Dense)          (None, 128)               32896     |
# |                                                               |
# | dense_38 (Dense)          (None, 64)                8256      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  sequential_25 (Sequential)  (None, 28, 28)            242832
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | dense_39 (Dense)          (None, 128)               8320      |
# |                                                               |
# | dense_40 (Dense)          (None, 256)               33024     |
# |                                                               |
# | dense_41 (Dense)          (None, 784)               201488    |
# |                                                               |
# | reshape_8 (Reshape)       (None, 28, 28)            0         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 484,944
# Trainable params: 484,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
model64.compile(optimizer='adam', loss='binary_crossentropy')

history64 = model64.fit(x_train, x_train, batch_size=128, epochs=50, shuffle=True, validation_split=0.1)
# Out:
# Epoch 1/50
# 422/422 [==============================] - 6s 12ms/step - loss: 0.3929 - val_loss: 0.3462
# Epoch 2/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3265 - val_loss: 0.3194
# Epoch 3/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3122 - val_loss: 0.3115
# Epoch 4/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.3054 - val_loss: 0.3055
# Epoch 5/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.3002 - val_loss: 0.3003
# Epoch 6/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2963 - val_loss: 0.2970
# Epoch 7/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2934 - val_loss: 0.2946
# Epoch 8/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2910 - val_loss: 0.2921
# Epoch 9/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2888 - val_loss: 0.2903
# Epoch 10/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2870 - val_loss: 0.2886
# Epoch 11/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2853 - val_loss: 0.2874
# Epoch 12/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2840 - val_loss: 0.2857
# Epoch 13/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2827 - val_loss: 0.2847
# Epoch 14/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2816 - val_loss: 0.2835
# Epoch 15/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2805 - val_loss: 0.2827
# Epoch 16/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2796 - val_loss: 0.2818
# Epoch 17/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2788 - val_loss: 0.2809
# Epoch 18/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2780 - val_loss: 0.2801
# Epoch 19/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2772 - val_loss: 0.2797
# Epoch 20/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2765 - val_loss: 0.2789
# Epoch 21/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2760 - val_loss: 0.2782
# Epoch 22/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2754 - val_loss: 0.2777
# Epoch 23/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2748 - val_loss: 0.2774
# Epoch 24/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2743 - val_loss: 0.2766
# Epoch 25/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2739 - val_loss: 0.2763
# Epoch 26/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2734 - val_loss: 0.2759
# Epoch 27/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2730 - val_loss: 0.2756
# Epoch 28/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2725 - val_loss: 0.2751
# Epoch 29/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2722 - val_loss: 0.2746
# Epoch 30/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2718 - val_loss: 0.2743
# Epoch 31/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2715 - val_loss: 0.2743
# Epoch 32/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2711 - val_loss: 0.2738
# Epoch 33/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2708 - val_loss: 0.2734
# Epoch 34/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2705 - val_loss: 0.2730
# Epoch 35/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2702 - val_loss: 0.2729
# Epoch 36/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2699 - val_loss: 0.2728
# Epoch 37/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2697 - val_loss: 0.2723
# Epoch 38/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2694 - val_loss: 0.2721
# Epoch 39/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2692 - val_loss: 0.2718
# Epoch 40/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2689 - val_loss: 0.2716
# Epoch 41/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2688 - val_loss: 0.2714
# Epoch 42/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2685 - val_loss: 0.2713
# Epoch 43/50
# 422/422 [==============================] - 5s 13ms/step - loss: 0.2683 - val_loss: 0.2713
# Epoch 44/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2682 - val_loss: 0.2708
# Epoch 45/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2679 - val_loss: 0.2708
# Epoch 46/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2678 - val_loss: 0.2706
# Epoch 47/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2676 - val_loss: 0.2704
# Epoch 48/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2674 - val_loss: 0.2703
# Epoch 49/50
# 422/422 [==============================] - 5s 11ms/step - loss: 0.2673 - val_loss: 0.2701
# Epoch 50/50
# 422/422 [==============================] - 5s 12ms/step - loss: 0.2671 - val_loss: 0.2701

# %%
plt.plot(history64.history['loss'], label='loss')
plt.plot(history64.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %%
decoded_imgs = model64(x_test[:10])

# %%
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    plt.title("Original", fontsize=12)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    plt.title("Reconstructed", fontsize=12)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
train_score16 = model16.evaluate(x_train, x_train, verbose = 0)
test_score16 = model16.evaluate(x_test, x_test, verbose = 0)

train_score32 = model32.evaluate(x_train, x_train, verbose = 0)
test_score32 = model32.evaluate(x_test, x_test, verbose = 0)

train_score64 = model64.evaluate(x_train, x_train, verbose = 0)
test_score64 = model64.evaluate(x_test, x_test, verbose = 0)

# %%
sizes = [16, 32, 64]
plt.plot(sizes, [train_score16, train_score32, train_score64], label="Train Mean Loss")
plt.plot(sizes, [test_score16, test_score32, test_score64], label="Test Mean Loss")
plt.xlabel("Representation size")
plt.xticks([16, 32, 64])
plt.legend()
